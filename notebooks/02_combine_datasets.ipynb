# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Setting plot style
sns.set_style("whitegrid")
plt.rcParams['figure.dpi'] = 100

# %%
# Load both datasets
df_math = pd.read_csv('../data/student-mat.csv', sep=';')
df_por = pd.read_csv('../data/student-por.csv', sep=';')

# %%
# Basic info
print("=== MATH DATASET ===")
print(df_math.info())
print("\n", df_math.describe())
print("\n", df_math.head())

print("\n=== PORTUGUESE DATASET ===")
print(df_por.info())
print("\n", df_por.describe())
print("\n", df_por.head())
# Out:
# === MATH DATASET ===
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
# ...

# %%
# Add a subject column (so you can distinguish rows after stacking)
df_math["subject"] = "math"
df_por["subject"]  = "portuguese"

# Stack (concatenate) both datasets into one DataFrame
df_all = pd.concat([df_math, df_por], axis=0, ignore_index=True)

# Sanity checks
print("Rows:", len(df_all))          # should be 1044
print(df_all["subject"].value_counts())
# Out:
# Rows: 1044
# subject
# portuguese    649
# math          395
# Name: count, dtype: int64

# %%
# Create risk categories based on final grade (G3)
# High: <10, Medium: 10–13, Low: 14+
bins = [-1, 9, 13, 20]  # G3 is 0–20
labels = ["High", "Medium", "Low"]

df_all["risk_category"] = pd.cut(df_all["G3"], bins=bins, labels=labels)

df_all["risk_category"].value_counts(dropna=False)
# Out:
# risk_category
# Medium    520
# Low       294
# High      230
# Name: count, dtype: int64

# %%
from pathlib import Path

project_root = Path.cwd().parent            # if your notebook is in the "notebooks" folder
out_path = project_root / "data" / "processed" / "combined_student_data.csv"

out_path.parent.mkdir(parents=True, exist_ok=True)
df_all.to_csv(out_path, index=False)

print("CWD:", Path.cwd())
print("Saved to:", out_path.resolve())
# Out:
# CWD: c:\Users\atilo\OneDrive\Desktop\Projects\student-performance\notebooks
# Saved to: C:\Users\atilo\OneDrive\Desktop\Projects\student-performance\data\processed\combined_student_data.csv

# %%
# Verify: 1,044 rows and no missing values
print("Rows:", df_all.shape[0])
assert df_all.shape[0] == 1044, f"Expected 1044 rows, got {df_all.shape[0]}"

missing_total = int(df_all.isna().sum().sum())
print("Total missing values:", missing_total)
assert missing_total == 0, f"Found {missing_total} missing values"
# Out:
# Rows: 1044
# Total missing values: 0
